# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers 
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Conv2D, Activation, MaxPooling2D, Dropout, Flatten

import tensorflow_addons as tfa
import cv2
import os 
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import datetime

from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
# from sklearn.metrics import accuracy_score
import random 
import time

AUTOTUNE = tf.data.AUTOTUNE

# %%
N_BEF_RES = 256
N_RES = 256 
# N_CLASSES = 143 
N_BATCH = 32

# %%
PATH = 'C:/Users/user/Desktop/Child Skin Disease'
os.listdir('C:/Users/user/Desktop/Child Skin Disease')
# Out:
# ['Total_Dataset', '소아피부질환 class.xlsx']

# %%
dataset = os.path.join(PATH, 'Total_Dataset')
dataset
# Out:
# 'C:/Users/user/Desktop/Child Skin Disease\\Total_Dataset'

# %%
# Train & test set
limit_num = 100
base_num = 100
train_dict = {}
test_dict = {} 

for i in range(6):
    files = os.listdir(os.path.join(dataset, f'H{i}'))
    
    for f in files: 
        imgs = glob(os.path.join(dataset, f'H{i}', f) + '/*.jpg')
        
        if len(imgs) > limit_num: 
            
            if f in train_dict:
                train_dict[f] = train_dict[f] + len(imgs)
            else:
                train_dict[f] = len(imgs)
            
for i in range(7, 10): 
    files = [val for val in list(train_dict.keys())]
    
    for f in files:
        imgs = glob(os.path.join(dataset, f'H{i}', f) + '/*.jpg')
        
        if f in test_dict:
            test_dict[f] = test_dict[f] + len(imgs) 
        else:
            test_dict[f] = len(imgs) 
        
train_dict, test_dict
# Out:
# ({'Abscess': 78,
#   'Acanthosis nigricans': 198,
#   'Acne': 1561,
#   'Acne neonatorum': 87,
#   'Acne scar integrated': 382,
#   'Acquired tufted hamangioma': 33,
#   'Alopecia areata': 2260,
#   'Anetoderma': 26,
#   'Angioedema': 23,
#   'Angiofibroma': 64,
#   'Angiokeratoma': 97,
#   'Angular cheilitis': 98,
#   'Aplasia cutis, congenital': 61,
#   "Beau's lines": 65,
#   "Becker's nevus": 315,
#   'Blue nevus': 163,
#   'Cafe-au-lait spot': 678,
#   'Cellulitis': 103,
#   'Cheilitis': 94,
#   'Chicken pox (varicella)': 330,
#   'Childhood granulomatous periorificial dermatitis': 211,
#   'Confluent and reticulated papillomatosis': 161,
#   'Congenital Hemangioma': 26,
#   'Contact dermatitis': 1050,
#   'Corn, Callus': 1377,
#   'Cutaneous larva migrans': 32,
#   'Cutaneous lupus erythematosus': 167,
#   'Cutis marmorata': 27,
#   'Cutis marmorata telangiectatica congenita (CMTC)': 46,
#   'Cyst integrated': 1458,
#   'Dermal Melanocytic Hamartoma': 264,
#   'Dermatofibroma': 630,
#   'Drug eruption': 464,
#   'Dyshidrotic eczema': 276,
#   'Eczema herpeticum': 190,
#   'Epidermal nevus': 322,
#   'Erythema dyschromicum perstans': 248,
#   'Erythema multiforme': 700,
#   'Erythema nodosum': 287,
#   'Fixed drug eruption': 280,
#   'Folliculitis': 858,
#   'Freckle': 180,
#   'Gianotti-Crosti Syndrome': 248,
#   'Graft Versus Host Disease': 89,
#   'Granuloma annulare': 190,
#   'Guttate psoriasis': 125,
#   'Halo nevus': 75,
#   'Hand eczema': 56,
#   'Hand, foot and mouth disease': 334,
#   'Hemangioma integrated': 596,
#   'Henoch-Schonlein purpura': 524,
#   'Herpes simplex infection': 209,
#   'Herpes zoster': 508,
#   'Ichthyosis': 144,
#   'ILVEN': 136,
#   'Impetigo': 451,
#   'Incontinentia pigmenti': 87,
#   'Infantile seborrheic dermatitis': 74,
#   'Ingrowing nail': 278,
#   'Insect bites and stings': 776,
#   'Juvenile xanthogranuloma': 410,
#   'Keloid scar': 970,
#   'Keratosis pilaris': 216,
#   'Lichen amyloidosis': 210,
#   'Lichen nitidus': 196,
#   'Lichen simplex chronicus': 161,
#   'Lichen striatus': 679,
#   'Linear scleroderma': 97,
#   'Livedo reticularis': 86,
#   'Livedoid vasculitis': 97,
#   'Localized scleroderma': 156,
#   'Lymphangioma': 88,
#   'Mastocytoma': 513,
#   'Melanocytic nevus': 1658,
#   'Melanonychia': 566,
#   'Milium': 439,
#   'Molluscum contagiosum': 840,
#   'Mongolian spot': 465,
#   'Neurofibroma': 94,
#   'Neurofibromatosis': 98,
#   'Nevus anemicus': 30,
#   'Nevus comedonicus': 15,
#   'Nevus depigmentosus': 551,
#   'Nevus lipomatous superficialis': 48,
#   'Nevus of Ota': 354,
#   'Nevus sebaceus': 588,
#   'Nevus spilus': 73,
#   'Normal': 2197,
#   'Nummular eczema': 622,
#   'Onychodystrophy': 803,
#   'Onycholysis': 183,
#   'Onychomycosis': 674,
#   'Palmoplantar keratoderma': 118,
#   'Paronychia': 128,
#   'Partial unilateral lentiginosis': 69,
#   'Perioral dermatitis': 653,
#   'Pigmented purpuric dermatosis': 200,
#   'Pilomatricoma': 120,
#   'Pitted keratolysis': 37,
#   'Pityriasis alba': 655,
#   'Pityriasis amiantacea': 63,
#   'Pityriasis lichenoides': 513,
#   'Pityriasis rosea': 489,
#   'Pityriasis versicolor': 577,
#   'Port-Wine stain': 953,
#   'Postinflammatory hyperpigmentation': 82,
#   'Postinflammatory hypopigmentation': 159,
#   'Progressive macular hypomelanosis': 74,
#   'Prurigo': 1388,
#   'Prurigo pigmentosa': 74,
#   'Psoriasis': 5437,
#   'Purpura': 66,
#   'Pyogenic granuloma': 270,
#   'Salmon patch': 249,
#   'Scabies': 118,
#   'Scar': 1382,
#   'Seborrheic dermatitis': 1045,
#   'Skin tag': 623,
#   'Spider angioma': 27,
#   'Staphylococcal scalded skin syndrome': 133,
#   'Steatocystoma multiplex': 111,
#   'Striae distensae': 155,
#   'Subungual hemorrhage': 143,
#   'Telangiectasia': 159,
#   'Tinea capitis': 17,
#   'Tinea corporis': 79,
#   'Tinea cruris': 15,
#   'Tinea faciale': 15,
#   'Tinea manus': 21,
#   'Tinea pedis': 33,
#   'Toxic epidermal necrolysis': 54,
#   'Trichotillomania': 119,
#   'Ulcer': 156,
#   'Urticaria': 917,
#   'Urticaria pigmentosa': 310,
#   'Vascular malformation': 74,
#   'Verruca plana': 1017,
#   'Viral exanthem': 306,
#   'Vitiligo': 1875,
#   'Wart': 1164,
#   'Congenital smooth muscle hamartoma': 12,
#   'Miliaria': 57},
#  {'Abscess': 200,
#   'Acanthosis nigricans': 549,
#   'Acne': 681,
#   'Acne neonatorum': 185,
#   'Acne scar integrated': 0,
#   'Acquired tufted hamangioma': 83,
#   'Alopecia areata': 1005,
#   'Anetoderma': 257,
#   'Angioedema': 118,
#   'Angiofibroma': 91,
#   'Angiokeratoma': 174,
#   'Angular cheilitis': 103,
#   'Aplasia cutis, congenital': 208,
#   "Beau's lines": 17,
#   "Becker's nevus": 286,
#   'Blue nevus': 306,
#   'Cafe-au-lait spot': 517,
#   'Cellulitis': 218,
#   'Cheilitis': 758,
#   'Chicken pox (varicella)': 471,
#   'Childhood granulomatous periorificial dermatitis': 48,
#   'Confluent and reticulated papillomatosis': 720,
#   'Congenital Hemangioma': 0,
#   'Contact dermatitis': 893,
#   'Corn, Callus': 0,
#   'Cutaneous larva migrans': 32,
#   'Cutaneous lupus erythematosus': 594,
#   'Cutis marmorata': 260,
#   'Cutis marmorata telangiectatica congenita (CMTC)': 276,
#   'Cyst integrated': 707,
#   'Dermal Melanocytic Hamartoma': 12,
#   'Dermatofibroma': 376,
#   'Drug eruption': 589,
#   'Dyshidrotic eczema': 59,
#   'Eczema herpeticum': 90,
#   'Epidermal nevus': 406,
#   'Erythema dyschromicum perstans': 588,
#   'Erythema multiforme': 746,
#   'Erythema nodosum': 286,
#   'Fixed drug eruption': 205,
#   'Folliculitis': 576,
#   'Freckle': 94,
#   'Gianotti-Crosti Syndrome': 0,
#   'Graft Versus Host Disease': 796,
#   'Granuloma annulare': 717,
#   'Guttate psoriasis': 172,
#   'Halo nevus': 152,
#   'Hand eczema': 25,
#   'Hand, foot and mouth disease': 81,
#   'Hemangioma integrated': 521,
#   'Henoch-Schonlein purpura': 325,
#   'Herpes simplex infection': 333,
#   'Herpes zoster': 204,
#   'Ichthyosis': 328,
#   'ILVEN': 337,
#   'Impetigo': 491,
#   'Incontinentia pigmenti': 381,
#   'Infantile seborrheic dermatitis': 156,
#   'Ingrowing nail': 296,
#   'Insect bites and stings': 456,
#   'Juvenile xanthogranuloma': 226,
#   'Keloid scar': 293,
#   'Keratosis pilaris': 343,
#   'Lichen amyloidosis': 113,
#   'Lichen nitidus': 875,
#   'Lichen simplex chronicus': 264,
#   'Lichen striatus': 320,
#   'Linear scleroderma': 268,
#   'Livedo reticularis': 165,
#   'Livedoid vasculitis': 290,
#   'Localized scleroderma': 41,
#   'Lymphangioma': 77,
#   'Mastocytoma': 307,
#   'Melanocytic nevus': 806,
#   'Melanonychia': 286,
#   'Milium': 504,
#   'Molluscum contagiosum': 510,
#   'Mongolian spot': 409,
#   'Neurofibroma': 247,
#   'Neurofibromatosis': 1045,
#   'Nevus anemicus': 39,
#   'Nevus comedonicus': 44,
#   'Nevus depigmentosus': 450,
#   'Nevus lipomatous superficialis': 0,
#   'Nevus of Ota': 328,
#   'Nevus sebaceus': 367,
#   'Nevus spilus': 545,
#   'Normal': 2031,
#   'Nummular eczema': 870,
#   'Onychodystrophy': 440,
#   'Onycholysis': 387,
#   'Onychomycosis': 283,
#   'Palmoplantar keratoderma': 451,
#   'Paronychia': 150,
#   'Partial unilateral lentiginosis': 77,
#   'Perioral dermatitis': 97,
#   'Pigmented purpuric dermatosis': 391,
#   'Pilomatricoma': 62,
#   'Pitted keratolysis': 23,
#   'Pityriasis alba': 55,
#   'Pityriasis amiantacea': 140,
#   'Pityriasis lichenoides': 690,
#   'Pityriasis rosea': 732,
#   'Pityriasis versicolor': 1050,
#   'Port-Wine stain': 330,
#   'Postinflammatory hyperpigmentation': 173,
#   'Postinflammatory hypopigmentation': 371,
#   'Progressive macular hypomelanosis': 153,
#   'Prurigo': 516,
#   'Prurigo pigmentosa': 422,
#   'Psoriasis': 2618,
#   'Purpura': 441,
#   'Pyogenic granuloma': 203,
#   'Salmon patch': 207,
#   'Scabies': 511,
#   'Scar': 628,
#   'Seborrheic dermatitis': 552,
#   'Skin tag': 361,
#   'Spider angioma': 341,
#   'Staphylococcal scalded skin syndrome': 514,
#   'Steatocystoma multiplex': 168,
#   'Striae distensae': 134,
#   'Subungual hemorrhage': 90,
#   'Telangiectasia': 133,
#   'Tinea capitis': 19,
#   'Tinea corporis': 8,
#   'Tinea cruris': 3,
#   'Tinea faciale': 14,
#   'Tinea manus': 5,
#   'Tinea pedis': 13,
#   'Toxic epidermal necrolysis': 314,
#   'Trichotillomania': 0,
#   'Ulcer': 115,
#   'Urticaria': 1122,
#   'Urticaria pigmentosa': 73,
#   'Vascular malformation': 40,
#   'Verruca plana': 611,
#   'Viral exanthem': 805,
#   'Vitiligo': 1291,
#   'Wart': 1054,
#   'Congenital smooth muscle hamartoma': 21,
#   'Miliaria': 72})

# %%
lists = sorted(train_dict.items())
lists

x, y = zip(*lists) 
plt.figure(figsize=(30, 20))
plt.plot(x, y)
plt.show()

# %%
N_CLASSES = len(train_dict)

# %%
train_images = [] 
test_images = []

for i in range(6):
    for key in train_dict.keys():
        img = glob(dataset + f'/H{str(i)}/{key}/*.jpg')
        train_images.extend(img) 
        
for i in range(7, 10):
    for key in train_dict.keys():
        img = glob(dataset + f'/H{str(i)}/{key}/*.jpg')
        test_images.extend(img) 
        
        
random.shuffle(train_images)
random.shuffle(test_images)
        
len(train_images), len(test_images)
# Out:
# (57558, 51092)

# %%
label_to_index = {}
for idx, key in zip(range(len(train_dict)), train_dict.keys()):
    label_to_index[key] = idx
    
label_to_index
# Out:
# {'Abscess': 0,
#  'Acanthosis nigricans': 1,
#  'Acne': 2,
#  'Acne neonatorum': 3,
#  'Acne scar integrated': 4,
#  'Acquired tufted hamangioma': 5,
#  'Alopecia areata': 6,
#  'Anetoderma': 7,
#  'Angioedema': 8,
#  'Angiofibroma': 9,
#  'Angiokeratoma': 10,
#  'Angular cheilitis': 11,
#  'Aplasia cutis, congenital': 12,
#  "Beau's lines": 13,
#  "Becker's nevus": 14,
#  'Blue nevus': 15,
#  'Cafe-au-lait spot': 16,
#  'Cellulitis': 17,
#  'Cheilitis': 18,
#  'Chicken pox (varicella)': 19,
#  'Childhood granulomatous periorificial dermatitis': 20,
#  'Confluent and reticulated papillomatosis': 21,
#  'Congenital Hemangioma': 22,
#  'Contact dermatitis': 23,
#  'Corn, Callus': 24,
#  'Cutaneous larva migrans': 25,
#  'Cutaneous lupus erythematosus': 26,
#  'Cutis marmorata': 27,
#  'Cutis marmorata telangiectatica congenita (CMTC)': 28,
#  'Cyst integrated': 29,
#  'Dermal Melanocytic Hamartoma': 30,
#  'Dermatofibroma': 31,
#  'Drug eruption': 32,
#  'Dyshidrotic eczema': 33,
#  'Eczema herpeticum': 34,
#  'Epidermal nevus': 35,
#  'Erythema dyschromicum perstans': 36,
#  'Erythema multiforme': 37,
#  'Erythema nodosum': 38,
#  'Fixed drug eruption': 39,
#  'Folliculitis': 40,
#  'Freckle': 41,
#  'Gianotti-Crosti Syndrome': 42,
#  'Graft Versus Host Disease': 43,
#  'Granuloma annulare': 44,
#  'Guttate psoriasis': 45,
#  'Halo nevus': 46,
#  'Hand eczema': 47,
#  'Hand, foot and mouth disease': 48,
#  'Hemangioma integrated': 49,
#  'Henoch-Schonlein purpura': 50,
#  'Herpes simplex infection': 51,
#  'Herpes zoster': 52,
#  'Ichthyosis': 53,
#  'ILVEN': 54,
#  'Impetigo': 55,
#  'Incontinentia pigmenti': 56,
#  'Infantile seborrheic dermatitis': 57,
#  'Ingrowing nail': 58,
#  'Insect bites and stings': 59,
#  'Juvenile xanthogranuloma': 60,
#  'Keloid scar': 61,
#  'Keratosis pilaris': 62,
#  'Lichen amyloidosis': 63,
#  'Lichen nitidus': 64,
#  'Lichen simplex chronicus': 65,
#  'Lichen striatus': 66,
#  'Linear scleroderma': 67,
#  'Livedo reticularis': 68,
#  'Livedoid vasculitis': 69,
#  'Localized scleroderma': 70,
#  'Lymphangioma': 71,
#  'Mastocytoma': 72,
#  'Melanocytic nevus': 73,
#  'Melanonychia': 74,
#  'Milium': 75,
#  'Molluscum contagiosum': 76,
#  'Mongolian spot': 77,
#  'Neurofibroma': 78,
#  'Neurofibromatosis': 79,
#  'Nevus anemicus': 80,
#  'Nevus comedonicus': 81,
#  'Nevus depigmentosus': 82,
#  'Nevus lipomatous superficialis': 83,
#  'Nevus of Ota': 84,
#  'Nevus sebaceus': 85,
#  'Nevus spilus': 86,
#  'Normal': 87,
#  'Nummular eczema': 88,
#  'Onychodystrophy': 89,
#  'Onycholysis': 90,
#  'Onychomycosis': 91,
#  'Palmoplantar keratoderma': 92,
#  'Paronychia': 93,
#  'Partial unilateral lentiginosis': 94,
#  'Perioral dermatitis': 95,
#  'Pigmented purpuric dermatosis': 96,
#  'Pilomatricoma': 97,
#  'Pitted keratolysis': 98,
#  'Pityriasis alba': 99,
#  'Pityriasis amiantacea': 100,
#  'Pityriasis lichenoides': 101,
#  'Pityriasis rosea': 102,
#  'Pityriasis versicolor': 103,
#  'Port-Wine stain': 104,
#  'Postinflammatory hyperpigmentation': 105,
#  'Postinflammatory hypopigmentation': 106,
#  'Progressive macular hypomelanosis': 107,
#  'Prurigo': 108,
#  'Prurigo pigmentosa': 109,
#  'Psoriasis': 110,
#  'Purpura': 111,
#  'Pyogenic granuloma': 112,
#  'Salmon patch': 113,
#  'Scabies': 114,
#  'Scar': 115,
#  'Seborrheic dermatitis': 116,
#  'Skin tag': 117,
#  'Spider angioma': 118,
#  'Staphylococcal scalded skin syndrome': 119,
#  'Steatocystoma multiplex': 120,
#  'Striae distensae': 121,
#  'Subungual hemorrhage': 122,
#  'Telangiectasia': 123,
#  'Tinea capitis': 124,
#  'Tinea corporis': 125,
#  'Tinea cruris': 126,
#  'Tinea faciale': 127,
#  'Tinea manus': 128,
#  'Tinea pedis': 129,
#  'Toxic epidermal necrolysis': 130,
#  'Trichotillomania': 131,
#  'Ulcer': 132,
#  'Urticaria': 133,
#  'Urticaria pigmentosa': 134,
#  'Vascular malformation': 135,
#  'Verruca plana': 136,
#  'Viral exanthem': 137,
#  'Vitiligo': 138,
#  'Wart': 139,
#  'Congenital smooth muscle hamartoma': 140,
#  'Miliaria': 141}

# %%
type(train_dict['Miliaria']),  type(base_num)
# Out:
# (int, int)

# %%
def train_skin_data(files):
    
    for file in files:
    
        f = file.decode('utf-8')
        
        img = cv2.imread(f, cv2.COLOR_BGR2YCR_CB)
        img = cv2.resize(img, (N_BEF_RES, N_BEF_RES))
        img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)

        idx = f.split('\\')[1].split('/')[2]
        lbl = tf.keras.utils.to_categorical(label_to_index[idx], len(train_dict))

        yield (img, lbl)    
        
        # if lower than base num, should apply data augmentation
        if base_num <= int(train_dict[idx]):

            # Btight 
            random_bright_tensor = tf.image.random_brightness(img, max_delta=128)
            random_bright_tensor = tf.clip_by_value(random_bright_tensor, 0, 255)
            random_bright_image = tf.keras.preprocessing.image.array_to_img(random_bright_tensor)
            yield (random_bright_tensor, lbl) 
    
            # rotation
            rotated_img = tf.image.rot90(img)        
            yield (rotated_img, lbl) 
            
            # curmix 
            cutmixed_img, cutmixed_lbl = cutmix(img, lbl)
            yield (cutmixed_img, cutmixed_lbl)

# %%
def test_skin_data(files):
    
    for file in files:
    
        f = file.decode('utf-8')
        
        img = cv2.imread(f, cv2.COLOR_BGR2YCR_CB)
        img = cv2.resize(img, (N_BEF_RES, N_BEF_RES))
        img = cv2.normalize(img, None, 0, 255, cv2.NORM_MINMAX)
        
        lbl = tf.keras.utils.to_categorical(label_to_index[f.split('\\')[1].split('/')[2]], len(train_dict))

        yield (img, lbl)

# %%
def cutmix(images, labels):
    # imgs = []; labs = []
    # for i in range(N_BATCH):
    APPLY = tf.cast(tf.random.uniform(()) >= 0.5, tf.int32)
    idx = tf.random.uniform((), 0, len(train_images), tf.int32)
    
    # random_img = 0 
    # random_lbl = 0 
    
    random_img = cv2.imread(train_images[idx], cv2.COLOR_BGR2YCR_CB)
    random_img = cv2.resize(random_img, (N_BEF_RES, N_BEF_RES))
    random_img = cv2.normalize(random_img, None, 0, 255, cv2.NORM_MINMAX)
    random_lbl = tf.keras.utils.to_categorical(label_to_index[train_images[idx].split('\\')[1].split('/')[2]], len(train_dict))

    W = N_RES
    H = N_RES
    lam = tf.random.uniform(())
    cut_ratio = tf.math.sqrt(1.-lam)
    cut_w = tf.cast(W * cut_ratio, tf.int32) * APPLY
    cut_h = tf.cast(H * cut_ratio, tf.int32) * APPLY

    cx = tf.random.uniform((), int(W/8), int(7/8*W), tf.int32)
    cy = tf.random.uniform((), int(H/8), int(7/8*H), tf.int32)

    xmin = tf.clip_by_value(cx - cut_w//2, 0, W)
    ymin = tf.clip_by_value(cy - cut_h//2, 0, H)
    xmax = tf.clip_by_value(cx + cut_w//2, 0, W)
    ymax = tf.clip_by_value(cy + cut_h//2, 0, H)

    mid_left = images[ymin:ymax, :xmin, :]
    # mid_mid = images[idx, ymin:ymax, xmin:xmax, :]
    mid_mid = random_img[ymin:ymax, xmin:xmax, :]
    mid_right = images[ymin:ymax, xmax:, :]
    middle = tf.concat([mid_left, mid_mid, mid_right], axis=1)
    top = images[:ymin, :, :]
    bottom = images[ymax:, :, :]
    new_img = tf.concat([top, middle, bottom], axis=0)
    # imgs.append(new_img)

    cut_w_mod = xmax - xmin
    cut_h_mod = ymax - ymin
    alpha = tf.cast((cut_w_mod*cut_h_mod)/(W*H), tf.float32)
    # label1 = labels[i]
    label1 = labels
    # label2 = labels[idx]
    label2 = random_lbl
    new_label = ((1-alpha)*label1 + alpha*label2)
    # labs.append(new_label)
        
    # new_imgs = tf.reshape(tf.stack(imgs), [-1, N_RES, N_RES, 3])
    # new_labs = tf.reshape(tf.stack(labs), [-1, N_CLASSES])

    return new_img, new_label

# %%
def get_dropout(input_tensor, p=0.3, mc=False):
    if mc: 
        layer = Dropout(p, name='top_dropout')
        return layer(input_tensor, training=True)
    else:
        return Dropout(p, name='top_dropout')(input_tensor, training=False)

# %%
import math
def create_class_weight(labels_dict, mu=0.15):
    total = np.sum(list(labels_dict.values()))
    keys = labels_dict.keys()
    class_weight = dict()
    
    for idx, key in zip(range(N_CLASSES), keys):
        score = math.log(mu*total/float(labels_dict[key]))
        class_weight[idx] = score
    
    return class_weight

class_weights = create_class_weight(train_dict)
# ttest
class_weights
# Out:
# {0: 3.097652451802324,
#  1: 5.262616166920322,
#  2: 1.9253225872376472,
#  3: 4.318154558079471,
#  4: 6.5153791354156905,
#  5: 4.073032100046486,
#  6: 1.8103636144578827,
#  7: 4.569468986360377,
#  8: 5.822231954855745,
#  9: 4.37531297191942,
#  10: 7.208526315975636,
#  11: 3.238234402423514,
#  12: 4.318154558079471,
#  13: 6.5153791354156905,
#  14: 4.435937593735854,
#  15: 5.599088403541535,
#  16: 1.531772513707354,
#  17: 3.0813919309305438,
#  18: 3.544964669845989,
#  19: 3.358378714265577,
#  20: 1.910208949427599,
#  21: 5.822231954855745,
#  22: 4.11748386261732,
#  23: 1.5560371357069849,
#  24: 7.208526315975636,
#  25: 4.723619666187635,
#  26: 2.8264996813017538,
#  27: 4.90594122298159,
#  28: 3.989650491107435,
#  29: 2.3564960520560185,
#  30: 6.5153791354156905,
#  31: 4.212794042421645,
#  32: 1.289632461702489,
#  33: 5.599088403541535,
#  34: 4.212794042421645,
#  35: 2.2958714302395835,
#  36: 3.5709401562492498,
#  37: 4.569468986360377,
#  38: 6.109914027307526,
#  39: 7.208526315975636,
#  40: 1.566619245037522,
#  41: 2.5737973277459996,
#  42: 2.108659888151437,
#  43: 3.4708566976922675,
#  44: 3.358378714265577,
#  45: 3.774539111490489,
#  46: 7.208526315975636,
#  47: 3.712018754509155,
#  48: 4.11748386261732,
#  49: 4.03047248562769,
#  50: 0.9899261962839063,
#  51: 3.519646861861699,
#  52: 1.0621970583067384,
#  53: 3.9126894499713067,
#  54: 5.822231954855745,
#  55: 3.2965033105474895,
#  56: 4.073032100046486,
#  57: 7.208526315975636,
#  58: 4.90594122298159,
#  59: 4.643576958514099,
#  60: 3.1654750481410856,
#  61: 4.073032100046486,
#  62: 3.774539111490489,
#  63: 4.03047248562769,
#  64: 7.208526315975636,
#  65: 2.8777929756893044,
#  66: 5.262616166920322,
#  67: 4.90594122298159,
#  68: 4.37531297191942,
#  69: 4.435937593735854,
#  70: 4.318154558079471,
#  71: 4.164003878252212,
#  72: 3.9126894499713067,
#  73: 2.6338153374722526,
#  74: 2.0552347214778566,
#  75: 3.316706017865009,
#  76: 4.500476114873425,
#  77: 1.671192048957099,
#  78: 3.2767006832513097,
#  79: 3.0813919309305438,
#  80: 6.5153791354156905,
#  81: 5.4167668467475805,
#  82: 4.643576958514099,
#  83: 3.989650491107435,
#  84: 6.109914027307526,
#  85: 7.208526315975636,
#  86: 3.519646861861699,
#  87: 1.856668182499569,
#  88: 4.810631043177265,
#  89: 4.90594122298159,
#  90: 7.208526315975636,
#  91: 4.643576958514099,
#  92: 3.1654750481410856,
#  93: 3.6821657913594743,
#  94: 6.109914027307526,
#  95: 1.8758075227102664,
#  96: 2.974419811378376,
#  97: 6.5153791354156905,
#  98: 4.90594122298159,
#  99: 2.288545390147511,
#  100: 5.1290847742958,
#  101: 3.712018754509155,
#  102: 1.8058489341033561,
#  103: 6.5153791354156905,
#  104: 6.5153791354156905,
#  105: 3.519646861861699,
#  106: 5.822231954855745,
#  107: 3.712018754509155,
#  108: 3.3798849194865404,
#  109: 5.262616166920322,
#  110: 0.27607842440312697,
#  111: 3.80732893431348,
#  112: 4.810631043177265,
#  113: 5.822231954855745,
#  114: 3.774539111490489,
#  115: 2.0668627594729756,
#  116: 2.2045800100301762,
#  117: 3.519646861861699,
#  118: 6.5153791354156905,
#  119: 2.93186019695958,
#  120: 3.447326200282073,
#  121: 4.37531297191942,
#  122: 5.822231954855745,
#  123: 5.262616166920322,
#  124: 4.643576958514099,
#  125: 3.5709401562492498,
#  126: 7.208526315975636,
#  127: 6.5153791354156905,
#  128: 6.109914027307526,
#  129: 7.208526315975636,
#  130: 4.810631043177265,
#  131: 3.653178254486222,
#  132: 4.723619666187635,
#  133: 2.0494710167611068,
#  134: 6.5153791354156905,
#  135: 5.4167668467475805,
#  136: 4.723619666187635,
#  137: 2.0045196288988403,
#  138: 2.2526992583743746,
#  139: 3.238234402423514,
#  140: 4.723619666187635,
#  141: 3.1654750481410856}

# %%
def run_expriment(model_name, train_dataset, val_dataset, batch_size=32, mc=False, epochs=100, n_splits=5): 
    
    if model_name == 'efficient':
        # base_model = keras.applications.EfficientNetB0(include_top=False, input_shape=(N_RES, N_RES, 3),  weights = 'imagenet')
        base_model = keras.applications.EfficientNetB7(include_top=False, input_shape=(N_RES, N_RES, 3),  weights = 'imagenet')
        base_model.trainable = True
        
        inputs = keras.Input(shape=(N_RES, N_RES, 3))
        x = base_model(inputs)
        x = keras.layers.GlobalAveragePooling2D()(x) 
        x = get_dropout(x, mc)
        x = keras.layers.Dense(N_CLASSES, activation='softmax')(x)
        model = tf.keras.Model(inputs=inputs, outputs=x)
        
    # VGG16 
    else:
        base_model = keras.applications.VGG16(include_top=False, input_shape=(N_RES, N_RES, 3),  weights = 'imagenet')
        base_model.trainable = True
        
        inputs = keras.Input(shape=(N_RES, N_RES, 3))
        x = base_model(inputs)
        x = keras.layers.Flatten(name = "avg_pool")(x) 
        x = keras.layers.Dense(512, activation='relu')(x)
        x = get_dropout(x, mc)
        x = keras.layers.Dense(256, activation='relu')(x)
        x = keras.layers.Dense(N_CLASSES, activation='softmax')(x)
        model = tf.keras.Model(inputs=inputs, outputs=x)
        

    sv = [tf.keras.callbacks.ModelCheckpoint(os.path.join(f'models/{model_name}_mc_{str(mc)}_{time.strftime("%Y%m%d-%H%M%S")}.h5'), 
                                            monitor='val_loss', 
                                            verbose=0, 
                                            save_best_only=True,
                                            save_weights_only=True, 
                                            mode='min', 
                                            save_freq='epoch'), 
          tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', 
                                           patience = 4, 
                                           min_delta = 0.01)]

    
    LR = 0.0001
    steps_per_epoch = len(train_images) // batch_size
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(LR, steps_per_epoch*30, 0.1, True)
    
    # model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), 
    #                 optimizer = tf.keras.optimizers.Adam(lr_schedule), 
    #                 metrics=['accuracy'])
    # model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), 
    #                 optimizer = tf.keras.optimizers.SGD(), 
    #                 metrics=['accuracy'])
    model.compile(loss=tfa.losses.SigmoidFocalCrossEntropy(), 
                    optimizer = tf.keras.optimizers.Adam(lr_schedule), 
                    metrics=['accuracy'])
    
    hist = model.fit(train_dataset,
                    validation_data = val_dataset,
                    epochs = epochs,
                    class_weight=class_weights, 
                    verbose = 1,
                    shuffle = True,
                    callbacks = [sv])
    
    # histories.append(hist)
    
    return model, hist

# %%
# train_dataset = create_dataset(train_images)
# test_dataset = create_dataset(test_images)

train_dataset = tf.data.Dataset.from_generator(train_skin_data, 
                                               output_types=(tf.float64, tf.float32), 
                                               output_shapes=(tf.TensorShape([N_BEF_RES, N_BEF_RES, 3]), tf.TensorShape([N_CLASSES])),
                                               args=[train_images])

test_dataset = tf.data.Dataset.from_generator(test_skin_data, 
                                              output_types=(tf.float64, tf.float32), 
                                              output_shapes=(tf.TensorShape([N_BEF_RES, N_BEF_RES, 3]), tf.TensorShape([N_CLASSES])),
                                              args=[test_images])

# %%
split_size = int(len(train_images) * 0.2)
split_train_dataset = train_dataset.skip(split_size)
split_val_dataset = train_dataset.take(split_size)

# new_split_train_dataset = split_train_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(N_BATCH, drop_remainder=True).prefetch(AUTOTUNE)
# val_dataset = val_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(N_BATCH, drop_remainder=True).prefetch(AUTOTUNE)

# batch_list = [1, 8, 16, 32, 64]
batch_list = [16, 32, 64]

for batch in batch_list:
    
    # new_split_train_dataset = split_train_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(batch, drop_remainder=True).prefetch(AUTOTUNE)
    # new_split_vbal_dataset = split_val_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(batch, drop_remainder=True).prefetch(AUTOTUNE)
    new_split_train_dataset = split_train_dataset.shuffle(150).batch(batch, drop_remainder=True).prefetch(AUTOTUNE)
    new_split_val_dataset = split_val_dataset.shuffle(150).batch(batch, drop_remainder=True).prefetch(AUTOTUNE)

    with tf.device('/device:GPU:0'):
        model, hist = run_expriment('efficient', new_split_train_dataset, new_split_val_dataset, batch_size=batch, mc=True, epochs=100)
# Out:
# Epoch 1/100
# 7810/7810 [==============================] - 4864s 612ms/step - loss: 1.0480 - accuracy: 0.4369 - val_loss: 0.3957 - val_accuracy: 0.5005
# Epoch 2/100
# 7810/7810 [==============================] - 5027s 635ms/step - loss: 0.6587 - accuracy: 0.5699 - val_loss: 0.3541 - val_accuracy: 0.5696
# Epoch 3/100
# 7810/7810 [==============================] - 4789s 605ms/step - loss: 0.5066 - accuracy: 0.6380 - val_loss: 0.3371 - val_accuracy: 0.5834
# Epoch 4/100
# 7810/7810 [==============================] - 4844s 612ms/step - loss: 0.4277 - accuracy: 0.6761 - val_loss: 0.3425 - val_accuracy: 0.5970
# Epoch 5/100
# 7810/7810 [==============================] - 4767s 602ms/step - loss: 0.3819 - accuracy: 0.6998 - val_loss: 0.3266 - val_accuracy: 0.6080
# Epoch 6/100
# 7810/7810 [==============================] - 4734s 598ms/step - loss: 0.3557 - accuracy: 0.7169 - val_loss: 0.3347 - val_accuracy: 0.6140
# Epoch 7/100
# 7810/7810 [==============================] - 4770s 602ms/step - loss: 0.3399 - accuracy: 0.7272 - val_loss: 0.3346 - val_accuracy: 0.6211
# Epoch 8/100
# 7810/7810 [==============================] - 4772s 602ms/step - loss: 0.3284 - accuracy: 0.7365 - val_loss: 0.3378 - val_accuracy: 0.6204
# Epoch 9/100
# 7810/7810 [==============================] - 4773s 602ms/step - loss: 0.3171 - accuracy: 0.7457 - val_loss: 0.3408 - val_accuracy: 0.6254
# Epoch 10/100
# 7810/7810 [==============================] - 4760s 601ms/step - loss: 0.3083 - accuracy: 0.7502 - val_loss: 0.3388 - val_accuracy: 0.6317
# Epoch 11/100
# 7810/7810 [==============================] - 4749s 600ms/step - loss: 0.3063 - accuracy: 0.7536 - val_loss: 0.3333 - val_accuracy: 0.6340
# Epoch 12/100
# 7810/7810 [==============================] - 4785s 604ms/step - loss: 0.3008 - accuracy: 0.7566 - val_loss: 0.3357 - val_accuracy: 0.6438
# Epoch 13/100
# 7810/7810 [==============================] - 4798s 606ms/step - loss: 0.2967 - accuracy: 0.7605 - val_loss: 0.3304 - val_accuracy: 0.6388
# Epoch 14/100
# 7810/7810 [==============================] - 4723s 596ms/step - loss: 0.2921 - accuracy: 0.7640 - val_loss: 0.3040 - val_accuracy: 0.6605
# Epoch 15/100
# 3278/7810 [===========>..................] - ETA: 43:08 - loss: 0.2635 - accuracy: 0.7798
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\workspace\child_skin\train.ipynb Cell 18' in <cell line: 11>()
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000050?line=15'>16</a> new_split_val_dataset = split_val_dataset.shuffle(150).batch(batch, drop_remainder=True).prefetch(AUTOTUNE)
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000050?line=17'>18</a> with tf.device('/device:GPU:0'):
# ---> <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000050?line=18'>19</a>     model, hist = run_expriment('efficient', new_split_train_dataset, new_split_val_dataset, batch_size=batch, mc=True, epochs=100)
#
# c:\workspace\child_skin\train.ipynb Cell 16' in run_expriment(model_name, train_dataset, val_dataset, batch_size, mc, epochs, n_splits)
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=45'>46</a> # model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=46'>47</a> #                 optimizer = tf.keras.optimizers.Adam(lr_schedule),
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=47'>48</a> #                 metrics=['accuracy'])
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=48'>49</a> # model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=49'>50</a> #                 optimizer = tf.keras.optimizers.SGD(),
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=50'>51</a> #                 metrics=['accuracy'])
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=51'>52</a> model.compile(loss=tfa.losses.SigmoidFocalCrossEntropy(),
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=52'>53</a>                 optimizer = tf.keras.optimizers.Adam(lr_schedule),
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=53'>54</a>                 metrics=['accuracy'])
# ---> <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=55'>56</a> hist = model.fit(train_dataset,
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=56'>57</a>                 validation_data = val_dataset,
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=57'>58</a>                 epochs = epochs,
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=58'>59</a>                 class_weight=class_weights,
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=59'>60</a>                 verbose = 1,
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=60'>61</a>                 shuffle = True,
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=61'>62</a>                 callbacks = [sv])
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=63'>64</a> # histories.append(hist)
#      <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000012?line=65'>66</a> return model, hist
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\engine\training.py:1389, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/engine/training.py?line=1386'>1387</a> logs = tmp_logs  # No error, now safe to assign to logs.
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/engine/training.py?line=1387'>1388</a> end_step = step + data_handler.step_increment
# -> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/engine/training.py?line=1388'>1389</a> callbacks.on_train_batch_end(end_step, logs)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/engine/training.py?line=1389'>1390</a> if self.stop_training:
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/engine/training.py?line=1390'>1391</a>   break
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\callbacks.py:438, in CallbackList.on_train_batch_end(self, batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=430'>431</a> """Calls the `on_train_batch_end` methods of its callbacks.
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=431'>432</a>
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=432'>433</a> Args:
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=433'>434</a>     batch: Integer, index of batch within the current epoch.
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=434'>435</a>     logs: Dict. Aggregated metric results up until this batch.
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=435'>436</a> """
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=436'>437</a> if self._should_call_train_batch_hooks:
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=437'>438</a>   self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\callbacks.py:297, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=294'>295</a>   self._call_batch_begin_hook(mode, batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=295'>296</a> elif hook == 'end':
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=296'>297</a>   self._call_batch_end_hook(mode, batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=297'>298</a> else:
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=298'>299</a>   raise ValueError(
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=299'>300</a>       f'Unrecognized hook: {hook}. Expected values are ["begin", "end"]')
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\callbacks.py:318, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=314'>315</a>   batch_time = time.time() - self._batch_start_time
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=315'>316</a>   self._batch_times.append(batch_time)
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=317'>318</a> self._call_batch_hook_helper(hook_name, batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=319'>320</a> if len(self._batch_times) >= self._num_batches_for_timing_check:
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=320'>321</a>   end_hook_name = hook_name
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\callbacks.py:356, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=353'>354</a> for callback in self.callbacks:
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=354'>355</a>   hook = getattr(callback, hook_name)
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=355'>356</a>   hook(batch, logs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=357'>358</a> if self._check_timing:
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=358'>359</a>   if hook_name not in self._hook_times:
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\callbacks.py:1034, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=1032'>1033</a> def on_train_batch_end(self, batch, logs=None):
# -> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=1033'>1034</a>   self._batch_update_progbar(batch, logs)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\callbacks.py:1106, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=1101'>1102</a>   self.seen += add_seen
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=1103'>1104</a> if self.verbose == 1:
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=1104'>1105</a>   # Only block async when verbose = 1.
# -> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=1105'>1106</a>   logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/callbacks.py?line=1106'>1107</a>   self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\utils\tf_utils.py:563, in sync_to_numpy_or_python_type(tensors)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=559'>560</a>     return t
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=560'>561</a>   return t.item() if np.ndim(t) == 0 else t
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=562'>563</a> return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\util\nest.py:914, in map_structure(func, *structure, **kwargs)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=909'>910</a> flat_structure = (flatten(s, expand_composites) for s in structure)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=910'>911</a> entries = zip(*flat_structure)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=912'>913</a> return pack_sequence_as(
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=913'>914</a>     structure[0], [func(*x) for x in entries],
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=914'>915</a>     expand_composites=expand_composites)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\util\nest.py:914, in <listcomp>(.0)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=909'>910</a> flat_structure = (flatten(s, expand_composites) for s in structure)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=910'>911</a> entries = zip(*flat_structure)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=912'>913</a> return pack_sequence_as(
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=913'>914</a>     structure[0], [func(*x) for x in entries],
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/util/nest.py?line=914'>915</a>     expand_composites=expand_composites)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\utils\tf_utils.py:557, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=553'>554</a> def _to_single_numpy_or_python_type(t):
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=554'>555</a>   # Don't turn ragged or sparse tensors to NumPy.
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=555'>556</a>   if isinstance(t, tf.Tensor):
# --> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=556'>557</a>     t = t.numpy()
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=557'>558</a>   # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/tf_utils.py?line=558'>559</a>   if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\framework\ops.py:1223, in _EagerTensorBase.numpy(self)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1199'>1200</a> """Copy of the contents of this Tensor into a NumPy array or scalar.
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1200'>1201</a>
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1201'>1202</a> Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1219'>1220</a>     NumPy dtype.
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1220'>1221</a> """
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1221'>1222</a> # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1222'>1223</a> maybe_arr = self._numpy()  # pylint: disable=protected-access
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1223'>1224</a> return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\framework\ops.py:1189, in _EagerTensorBase._numpy(self)
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1186'>1187</a> def _numpy(self):
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1187'>1188</a>   try:
# -> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1188'>1189</a>     return self._numpy_internal()
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1189'>1190</a>   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/framework/ops.py?line=1190'>1191</a>     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
split_size = int(len(train_images) * 0.2)
split_train_dataset = train_dataset.skip(split_size)
splot_val_dataset = train_dataset.take(split_size)

# %%
# new_split_train_dataset = split_train_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(N_BATCH).map(cutmix, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
# val_dataset = val_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(N_BATCH).map(cutmix, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
new_split_train_dataset = split_train_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(N_BATCH, drop_remainder=True).prefetch(AUTOTUNE)
val_dataset = val_dataset.map(aug, num_parallel_calls=AUTOTUNE).batch(N_BATCH, drop_remainder=True).prefetch(AUTOTUNE)

# %%
with tf.device('/device:GPU:0'):
    model, hist = run_expriment('efficient', new_split_train_dataset, val_dataset, mc=True, epochs=100)
# Out:
# Epoch 1/100
# 1312/1312 [==============================] - 426s 263ms/step - loss: 6.9445 - accuracy: 0.3029 - val_loss: 2.1484 - val_accuracy: 0.4327
# Epoch 2/100
# 1312/1312 [==============================] - 412s 266ms/step - loss: 4.4906 - accuracy: 0.4926 - val_loss: 1.7297 - val_accuracy: 0.5252
# Epoch 3/100
# 1312/1312 [==============================] - 414s 267ms/step - loss: 3.5900 - accuracy: 0.5775 - val_loss: 1.5232 - val_accuracy: 0.5761
# Epoch 4/100
# 1312/1312 [==============================] - 415s 268ms/step - loss: 3.0350 - accuracy: 0.6337 - val_loss: 1.4046 - val_accuracy: 0.6078
# Epoch 5/100
# 1312/1312 [==============================] - 416s 268ms/step - loss: 2.6196 - accuracy: 0.6778 - val_loss: 1.3935 - val_accuracy: 0.6206
# Epoch 6/100
# 1312/1312 [==============================] - 422s 272ms/step - loss: 2.2622 - accuracy: 0.7155 - val_loss: 1.3055 - val_accuracy: 0.6388
# Epoch 7/100
# 1312/1312 [==============================] - 418s 269ms/step - loss: 1.9705 - accuracy: 0.7488 - val_loss: 1.2880 - val_accuracy: 0.6471
# Epoch 8/100
# 1312/1312 [==============================] - 413s 267ms/step - loss: 1.7132 - accuracy: 0.7803 - val_loss: 1.2868 - val_accuracy: 0.6537
# Epoch 9/100
# 1312/1312 [==============================] - 417s 269ms/step - loss: 1.4710 - accuracy: 0.8090 - val_loss: 1.2875 - val_accuracy: 0.6623
# Epoch 10/100
# 1312/1312 [==============================] - 418s 269ms/step - loss: 1.2679 - accuracy: 0.8347 - val_loss: 1.2454 - val_accuracy: 0.6764
# Epoch 11/100
# 1312/1312 [==============================] - 412s 266ms/step - loss: 1.0856 - accuracy: 0.8571 - val_loss: 1.2587 - val_accuracy: 0.6742
# Epoch 12/100
# 1312/1312 [==============================] - 414s 267ms/step - loss: 0.9433 - accuracy: 0.8764 - val_loss: 1.2764 - val_accuracy: 0.6798
# Epoch 13/100
# 1312/1312 [==============================] - 417s 268ms/step - loss: 0.8013 - accuracy: 0.8961 - val_loss: 1.3070 - val_accuracy: 0.6760
# Epoch 14/100
# 1312/1312 [==============================] - 414s 267ms/step - loss: 0.7058 - accuracy: 0.9073 - val_loss: 1.3354 - val_accuracy: 0.6817

# %%
# test_dataset[0][0]test_dataset
# y_pred = model.predict(test_dataset) 
test_dataset = tf.data.Dataset.from_generator(get_skin_data, 
                                            output_types=(tf.float64, tf.float32), 
                                            output_shapes=(tf.TensorShape([224, 224, 3]), tf.TensorShape([N_CLASSES])),
                                            args=[test_images]).batch(64)

# test_dataset
y_pred = model.predict(test_dataset)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# c:\workspace\child_skin\train.ipynb Cell 23' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000054?line=2'>3</a> test_dataset = tf.data.Dataset.from_generator(get_skin_data,
#       <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000054?line=3'>4</a>                                             output_types=(tf.float64, tf.float32),
#       <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000054?line=4'>5</a>                                             output_shapes=(tf.TensorShape([224, 224, 3]), tf.TensorShape([N_CLASSES])),
#       <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000054?line=5'>6</a>                                             args=[test_images]).batch(64)
#       <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000054?line=7'>8</a> # test_dataset
# ----> <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000054?line=8'>9</a> y_pred = model.predict(test_dataset)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# 2 root error(s) found.
#   (0) INVALID_ARGUMENT:  TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
# Traceback (most recent call last):
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\ops\script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1047, in generator_py_func
#     raise TypeError(
#
# TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 	 [[IteratorGetNext/_2]]
#   (1) INVALID_ARGUMENT:  TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
# Traceback (most recent call last):
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\ops\script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1047, in generator_py_func
#     raise TypeError(
#
# TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_predict_function_1784584]

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# c:\workspace\child_skin\train.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/workspace/child_skin/train.ipynb#ch0000055?line=0'>1</a> y_pred = model.predict(test_dataset)
#
# File c:\ProgramData\Miniconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/ProgramData/Miniconda3/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# 2 root error(s) found.
#   (0) INVALID_ARGUMENT:  TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
# Traceback (most recent call last):
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\ops\script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1047, in generator_py_func
#     raise TypeError(
#
# TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 	 [[IteratorGetNext/_2]]
#   (1) INVALID_ARGUMENT:  TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
# Traceback (most recent call last):
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\ops\script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\ProgramData\Miniconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1047, in generator_py_func
#     raise TypeError(
#
# TypeError: `generator` yielded an element of shape (256, 256, 3) where an element of shape (224, 224, 3) was expected.
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_predict_function_1784584]

# %%
# hist
# for hist in histories:
plt.figure(1, figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
